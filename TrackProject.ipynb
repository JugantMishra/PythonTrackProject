# %%
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.image as mpimg

# %%
def print_in_color(txt_msg,fore_tupple,back_tupple,):
    #prints the text_msg in the foreground color specified by fore_tupple with the background specified by back_tupple 
    #text_msg is the text, fore_tupple is foregroud color tupple (r,g,b), back_tupple is background tupple (r,g,b)
    rf,gf,bf=fore_tupple
    rb,gb,bb=back_tupple
    msg='{0}' + txt_msg
    mat='\33[38;2;' + str(rf) +';' + str(gf) + ';' + str(bf) + ';48;2;' + str(rb) + ';' +str(gb) + ';' + str(bb) +'m' 
    print(msg .format(mat))

# %%
sdir=r'C:\Users\LENOVO\Desktop\butterflies'
train_dir=os.path.join(sdir, 'train')
msg='{0:8s}{1:4s}{2:^25s}{1:4s}{3:8s}{1:3s}{4:8s}{1:3s}{5:7s}{6}'
msg=msg.format('Class Id', ' ', 'Ball Type', 'Train ','Test', 'Valid ','\n')
print_in_color(msg, (0,255,255), (0,0,0))
species_list= sorted(os.listdir(train_dir))
for i, specie in enumerate (species_list):
    file_path=os.path.join(train_dir,specie)
    train_files_list=os.listdir(file_path)
    train_file_count=str(len(train_files_list))
    msg='{0:^8s}{1:4s}{2:^25s}{1:4s}{3:^8s}{1:1s}{4:^8s}{1:3s}{5:^8s}'
    msg=msg.format(str(i), ' ',specie, train_file_count,'5', '5')
    toggle=i% 2   
    if toggle==0:
        back_color=(255,255,255)
    else:
        back_color=(191, 239, 242)
    print_in_color(msg, (0,0,0), back_color)
# Out:
# Class Id            Ball Type            Train      Test       Valid
#
#    0                 adonis                 96       5          5
#    1             american snoot            105       5          5
#    2                  an 88                 92       5          5
#    3             banded peacock             91       5          5
#    4              beckers white            116       5          5
#    5            black hairstreak            90       5          5
#    6              cabbage white             92       5          5
#    7                chestnut                90       5          5
#    8           clodius parnassian           77       5          5
#    9             clouded sulphur            95       5          5
#    10              copper tail             134       5          5
#    11                crecent                66       5          5
#    12             crimson patch            103       5          5
#    13             eastern coma              96       5          5
#    14              gold banded             104       5          5
#    15             great eggfly             111       5          5
#    16            grey hairstreak            98       5          5
#    17             indra swallow            115       5          5
#    18                 julia                115       5          5
#    19             large marble              79       5          5
#    20               malachite              104       5          5
#    21           mangrove skipper            90       5          5
#    22               metalmark              108       5          5
#    23                monarch                80       5          5
#    24             morning cloak             90       5          5
#    25            orange oakleaf            100       5          5
#    26              orange tip               90       5          5
#    27            orchard swallow            81       5          5
#    28             painted lady             112       5          5
#    29              paper kite               92       5          5
#    30                peacock                97       5          5
#    31              pine white               96       5          5
#    32           pipevine swallow            94       5          5
#    33           purple hairstreak          113       5          5
#    34             question mark            110       5          5
#    35              red admiral              91       5          5
#    36          red spotted purple           95       5          5
#    37            scarce swallow            139       5          5
#    38          silver spot skipper          94       5          5
#    39            sixspot burnet            101       5          5
#    40                skipper               136       5          5
#    41               sootywing              128       5          5
#    42           southern dogface            94       5          5
#    43            straited queen             96       5          5
#    44          two barred flasher           82       5          5
#    45                ulyses                 72       5          5
#    46                viceroy                88       5          5
#    47              wood satyr              102       5          5
#    48          yellow swallow tail         107       5          5
#    49            zebra long wing           108       5          5

# %%
test_dir=os.path.join(sdir, 'test')
classes=len(os.listdir(test_dir))
fig = plt.figure(figsize=(20,20))
if classes % 5==0:
    rows=int(classes/5)
else:
    rows=int(classes/5) +1    
for row in range(rows):
    for column in range(5):
        i= row * 5 + column         
        if i>classes-1:
            break            
        specie=species_list[i]
        species_path=os.path.join(test_dir, specie)
        f_path=os.path.join(species_path, '1.jpg')        
        img = mpimg.imread(f_path)
        a = fig.add_subplot(rows, 5, i+1)
        imgplot=plt.imshow(img)
        a.axis("off")
        a.set_title(specie)
